# %% [markdown]
# # Run the Python file containing the SFGPL examples

# %%
import subprocess
import os
from SFGPL import *

# %% [markdown]
# ## Set default directories

# %%
PY_SAMPLES_DIR="py/samples/"
OUT_FILES_DIR="out/"

# %% [markdown]
# ## Set file settings

# %% [markdown]
# ### Enumerate the Python and output JSON files included in the project.

# %%
file_datas={
    "sample01":{
        "py":PY_SAMPLES_DIR+"sample01.py",
        "json":OUT_FILES_DIR+"sample01.json"
    },
    "sample02":{
        "py":PY_SAMPLES_DIR+"sample02.py",
        "json":OUT_FILES_DIR+"sample02.json"
    },
}

# %% [markdown]
# ### List files to be excluded.

# %%
exclusion_key_list=[
    "sample02"
]

# %% [markdown]
# ## Run Python files

# %%
run_pys=[file_datas[key]["py"] for key in file_datas if key not in exclusion_key_list]
out_jsons=[file_datas[key]["json"] for key in file_datas if key not in exclusion_key_list]

# %%
# List of Python files to be executed
for p in run_pys:
    print(p)
# Out:
# py/samples/sample01.py

# %%
for py_path in run_pys:
    #subprocess.run(["python",py_path])
    # !python $py_path
# Out:
# ma ga so fa 'student';
# ma ge so fa 'student';
# ma lan gi so fa 'student';
# ma len gi so fa 'student';
# ma don ga so don fa 'student';
# ma don ge so don fa 'student';
# ma don lan gi so don fa 'student';
# ma don len gi so don fa 'student';
# mi lan gi so ba fa 'pen' fa 'notebook';
# mi lan gi so be fa 'pen' fa 'notebook';
# mi lan gi so bu fa 'pen' fa 'notebook';
# mi lan gi so bo fa 'pen' fa 'notebook';
# mi lan gi so fa 'pen';
# pa mi lan gi so fa 'pen';
# di mi lan gi so fa 'pen';
# pa di mi lan gi so fa 'pen';
# du mi lan gi so fa 'pen';
# pa du mi lan gi so fa 'pen';
# ti ge sa 'tell' ga pen gi;
# pa ti ge sa 'tell' ga pen gi;
# di ti ge sa 'tell' ga pen gi;
# pa di ti ge sa 'tell' ga pen gi;
# du ti ge sa 'tell' ga pen gi;
# pa du ti ge sa 'tell' ga pen gi;
# te lan gi sa 'write' fa 'book';
# pa te lan gi sa 'write' fa 'book';
# di te lan gi sa 'write' fa 'book';
# pa di te lan gi sa 'write' fa 'book';
# du te lan gi sa 'write' fa 'book';
# pa du te lan gi sa 'write' fa 'book';
# pe mi lan gi so fa 'pen' te lan gi sa 'write' fa 'book';
# pu mi lan gi so fa 'pen' te lan gi sa 'write' fa 'book';
# po mi lan gi so fa 'pen' pa te lan gi sa 'write' fa 'book';
# ba mi lan gi so fa 'pen' te lan gi sa 'write' fa 'book';
# be mi lan gi so fa 'pen' te lan gi sa 'write' fa 'book';
# bu mi lan gi so fa 'pen' te lan gi sa 'write' fa 'book';
# bo mi lan gi so fa 'pen' te lan gi sa 'write' fa 'book';
# pi mi lan gi so fa 'pen' ti ge sa 'tell' ga pen gi;
# ti ge sa 'tell' lan gi de te lan gi sa 'buy' fa 'pen';
# bi mi lan gi so fa 'pen' ti ge sa 'tell' ga pen gi de ti ge sa 'tell' lan gi de te lan gi sa 'buy' fa 'pen';
# ma ga so mu fa 'employee' so fa 'company';
# ma ge so mu fa 'employee' so fa 'company';
# me ga so la 'sad';
# me ge sa 'seem' la 'sad';
# mi ga so me ma gu so san fa 'table' so la 'red';
# mi ga so me ma gu so san fa 'table' so la 'blue';
# ta ga na sa 'go' li pun mu ga so san fa 'school';
# ta ga na sa 'go' li pun mu ge so san fa 'school';
# ta ga na sa 'go' li pun mu lan gi so san fa 'school';
# ta ga na sa 'go' li pun mu len gi so san fa 'school';
# ta ga na sa 'go' li pun mu don ga so san fa 'school';
# ta ga na sa 'go' li pun mu don ge so san fa 'school';
# ta ga na sa 'go' li pun mu don lan gi so san fa 'school';
# ta ga na sa 'go' li pun mu don len gi so san fa 'school';
# mo me ma gu so san fa 'table' so la 'red' so wan me ma gu so san fa 'table' so la 'blue';
# mo me ma gu so san fa 'table' so la 'blue' so ke wan me ma gu so san fa 'table' so la 'red';
# te ge sa 'like' fi sa 'talk';
# di te ge sa 'measure' fu wan;
# di tu ge so ga fa 'teacher';
# di tu ga so ge fa 'teacher';
# di tu ga so lan gi fa 'teacher';
# di tu ga so len gi fa 'teacher';
# di tu ge so don ga fa 'teacher';
# di tu ga so don ge fa 'teacher';
# di tu ga so don lan gi fa 'teacher';
# di tu ga so don len gi fa 'teacher';
# di to ge so ga la 'happy';
# di to ga so ge la 'happy';
# di to ga so lan gi la 'happy';
# di to ga so len gi la 'happy';
# di to ge so don ga la 'happy';
# di to ga so don ge la 'happy';
# di to ga so don lan gi la 'happy';
# di to ga so don len gi la 'happy';
# ma ga so lan fo;
# ma ge so len fo;
# di ta ma gu so san fa 'book' na ne sa 'write' li tan tin ga;
# di ta ma go so san fa 'book' na ne sa 'write' li tan tin ga;
# di te ga ni sa 'write' ma gu so san fa 'book';
# di te ga ni sa 'write' ma go so san fa 'book';
# ta ga na nu gen li pun mu ge so san fa 'school';
# ta dan fa 'apple' si la 'red';
# te don ga na su fa 'zoom' ba li pun mu don ga so fa 'company' la 'recently' din don fa 'meeting';
# me ma gu so san fa 'apple' so ka la 'red' la 'green';
# me mi ge so san fa 'plan' so ka lu ni sa 'interest' li tan mi don ga so san fa 'project';
# me gu so lo;
# me gu so ke lo;
# te lan gi sa 'buy' fa 'book';
# da di te ben wa sa 'buy' fa 'book';
# da di te lan gi sa 'buy' wa;
# da di te lan gi na sa 'buy' li pin wa fa 'book';
# da di te lan gi na sa 'buy' li pun wa fa 'book';
# da di te lan gi na sa 'buy' li pon wa fa 'book';
# da di te lan gi na sa 'buy' li ban wa fa 'book';
# di te lan gi ken fa 'door';
# di te pan wa ken fa 'door';
# di te ben wa ken fa 'door';
# di te bin wa ken fa 'door';
# di te bun wa ken fa 'door';
# di te ben wa ken fa 'door';
# ta ma gu so fa 'door' na ne kan li bon fa 'wood';
# da ta ma gu so fa 'door' na ne kan li bon wa;
# di ta ga na sa 'go' ka li fan pun fa 'Osaka' li fen pun fa 'Tokyo';
# ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach';
# ta ge na sa 'go' li fon fo;
# ta ga na sa 'stay' li pun fa 'home';
# pa ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach';
# pe ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach' ta ge na sa 'go' li fon fo;
# pi ta ge na sa 'go' li fon fo ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach';
# bi ta ge na sa 'go' li fon fo ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach' ta ga na sa 'stay' li pun fa 'home';
# pu ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach' ta ge na sa 'go' li fon fo;
# po ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach' ta ge na sa 'go' li fon fo;
# ba ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach' ta ge na sa 'go' li fon fo;
# be ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach' ta ge na sa 'go' li fon fo;
# bu ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach' ta ge na sa 'go' li fon fo;
# bo ta ga na sa 'go' li pun te ga sa 'buy' fa 'peach' ta ge na sa 'go' li fon fo;
# du ta ga na na sa 'go' li pun te ga sa 'buy' fa 'peach' li fin ta ge na sa 'go' li fon fo;
# di te ga na sa 'research' li ban fa 'the_internet' fa 'Python';
# di du te ga na sa 'research' li ban fa 'the_internet' fa 'Python';
# di te ga na na sa 'research' la 'can' li ban fa 'the_internet' fa 'Python';
# di ma ga sa 'become' ben fi sa 'teach';
# di ma ge sa 'become' ben fi sa 'teach';
# ta ga na sa 'go' ka li pun fa 'Tokyo' li ten tin ge;
# te ga sa 'study' tan tin ma fa 'computer' so fa 'science';
# me fa 'ball' so li fun fa 'box';
# me fa 'ball' so li fon fa 'box';
# me fa 'ball' so li man fa 'box';
# me fa 'ball' so li min man fa 'box';
# me fa 'ball' so li men fa 'box';
# me fa 'ball' so li min men fa 'box';
# me fa 'ball' so li mun fa 'box';
# me fa 'ball' so li min mun fa 'box';
# me fa 'ball' so li mon fa 'box';
# me fa 'ball' so li min mon fa 'box';
# me fa 'ball' so li nan fa 'box';
# me fa 'ball' so li nen fa 'box';
# me fa 'ball' so li tun fa 'box';
# me fa 'ball' so li tun fun fa 'box';
# me fa 'ball' so li ton min fa 'box';
# me fa 'ball' so li ton fun fa 'box';
# me dan don me fa 'ball' so li ton fun fa 'box' so la 'red';
# me den don me fa 'ball' so li ton fun fa 'box' so la 'red';
# me din don me fa 'ball' so li ton fun fa 'box' so la 'red';
# me dun me fa 'ball' so li ton fun fa 'box' so la 'red';
# di ta ga na kin li nan fa 'box';
# di ta ga na kin li nen fa 'box';
# di ta don ga na kin li nen fa 'box';
# di ta ge na kin li nen fa 'box';
# di ta don ge na kin li nen fa 'box';
# di ta lan gi na kin li nen fa 'box';
# di ta len gi na kin li nen fa 'box';
# di ta pen gi na kin li nen fa 'box';
# di ta don gi na kin li nen fa 'box';
# di te ga sa 'put' mi ga so san fa 'ball';
# di te ga sa 'put' mi don ga so san fa 'ball';
# di te ga sa 'put' mi ge so san fa 'ball';
# di te ga sa 'put' mi don ge so san fa 'ball';
# di te ga sa 'put' mi lan gi so san fa 'ball';
# di te ga sa 'put' mi len gi so san fa 'ball';
# di te ga sa 'put' mi pen gi so san fa 'ball';
# di te ga sa 'put' mi don gi so san fa 'ball';
# di ti ge so ga gu;
# di ti ge so don ga don gu;
# di ti ga so ge gu;
# di ti ga so don ge don gu;
# di ti ga so lan ge gu;
# di ti ga so len ge gu;
# di ti ga so pen ge gu;
# di ti ga so don ge don gu;
# ma ma gu so fa 'pen' so sen ga;
# ma ma gu so fa 'pen' so sen don ga;
# ma ma gu so fa 'pen' so sen ge;
# ma ma gu so fa 'pen' so sen don ge;
# ma ma gu so fa 'pen' so sen lan gi;
# ma ma gu so fa 'pen' so sen len gi;
# ma ma gu so fa 'pen' so sen pen gi;
# ma ma gu so fa 'pen' so sen don gi;
# te ga sa 'like' sin ga;
# te don ga sa 'like' sin don ga;
# te ga sa 'like' sin ge;
# te don ga sa 'like' sin don ge;
# te lan gi sa 'like' sin lan gi;
# te len gi sa 'like' sin len gi;
# te pen gi sa 'like' sin pen gi;
# te don gi sa 'like' sin don gi;
# di te ga kan sun fa 'table';
# di te ga kan sun fa 'chair';
# di te ga kan son fa 'table';
# ma ma gu so san fa 'machine' so son fa 'power';
# ta ga na sa 'go' li pun go;
# di ta ga na sa 'go' li pun go;
# di ta ge ni sa 'eat';
# di ta ga na sa 'go' ka li pun go li pin fin di ta ge ni sa 'eat';
# di ta ga na sa 'go' ka li pun go li pin non di ta ge ni sa 'eat';
# di ta ga na sa 'go' ka li pun go li pin nun di ta ge ni sa 'eat';
# ma gu so fa 'machine';
# ma go so fa 'machine';
# ma don gu so don fa 'machine';
# ma don go so don fa 'machine';
# di te we sa 'open' fa 'door';
# di te we sa 'close' fa 'door';
# te ga kan fa 'bag';
# te ge kan fa 'bag';
# te ga ken fa 'bag';
# te ge ken fa 'bag';
# di ta ga na kin li pun fa 'Tokyo';
# ta ga na kin li tan fa 'engineer';
# ta ga na kun li tun pun mi ga so san fa 'home';
# ta ga na kun li tun pun mi ga so san fa 'home';
# di te ga kon fa 'rice';
# di te ga na kon li tun fun fa 'box' fa 'ball';
# di ti ga gan ge mi ga so san fa 'bag';
# di ti ga gan ge me fa 'notice' so la 'important';
# ta ga na gen li pun mi ge so san fa 'home';
# ta ga na gen li pun fa 'Tokyo';
# di te ga gin fa 'computer';
# di te ge gin fa 'computer';
# di te ga gun fa 'doctor';
# di te ga gun fa 'clerk';
# me fa 'window' so wan;
# me fa 'stick' so wan;
# me fa 'window' so win;
# me fa 'stick' so win;
# me don ga so wen;
# me ba ge ga so wen;
# me ma gu so san fa 'room' so won;
# me ma gu so san fa 'table' so won;
# di te ga na sa 'study' ka li fan pin fa '10am' li fen pin fa '12am' fa 'mathematics';
# di ta ga na sa 'work' ka li fan pin fa '8am' li fen pin fa '8pm';
# me me dan don fa 'student' so li fun mu ga so san fa 'school' so la 'wise';
# me me den don fa 'student' so li fun mu ga so san fa 'school' so la 'wise';
# me me din don fa 'student' so li fun mu ga so san fa 'school' so la 'wise';
# me me dun don fa 'student' so li fun mu ga so san fa 'school' so la 'wise';
# ta ga na nu sa 'study' ka li pin gu li pin fan fa '8:00';
# te ga na nu sa 'seen' li ma fa 'three' so fa 'time' ma gu so san fa 'movie';
# te ga na nu sa 'finish' la 'already' mi ga so san fa 'homework';
# di ta ga na sa 'go' ka li pun mu ga so san fa 'school' li ten tin mi ga so san fa 'friend';
# di ta ga na sa 'go' ka li pun mu ga so san fa 'school' li non pin fa '8am';
# di ta ga na sa 'go' ka li pun mu ga so san fa 'school' li nun pin fa '8am';
# di ta ga na sa 'go' ka li pun mu ga so san fa 'school' li pon fa 'procedure';
# te ga sa 'like' pan gu;
# te ga sa 'like' pen gu;
# te ga sa 'like' pin gu;
# te ga sa 'like' pun gu;
# te ga sa 'like' pon gu;
# te ga sa 'like' ban gu;
# te ga sa 'like' ben gu;
# te ga sa 'like' bin gu;
# te ga sa 'like' bun gu;
# te ga sa 'like' bon gu;
# te ga sa 'like' fi sa 'read';
# di te ga sa 'decide' fu la 'long';
# ta den ma don gu so san don fa 'leaf' si la 'red';
# di te ga su fa 'e-mail' ge;
# di ta ga na sa 'go' li pun fa 'France';
# di me ga so lu ne sa 'surprise';
# te ga sa 'like' te fo sa 'watch' fa 'Youtube';
# te ga sa 'like' te fo sa 'play' fa 'Minecraft';
# te ga sa 'like' fa 'programming';
# te ga si wen fi sa 'program';
# me ma gu so san fa 'table' so won;
# me ba ma gu so san fa 'table' fa 'sea' so ka wen won;
# mi ga so me ba ma gu so san fa 'table' fa 'sea' so ka wen won;
# ti ga sa 'lend' lan gi mi ga so me ba ma gu so san fa 'table' fa 'sea' so ka wen won;
# ti ga na sa 'lend' la 'will' lan gi mi ga so me ba ma gu so san fa 'table' fa 'sea' so ka wen won;
# di ti ga sa 'lend' lan gi mi ga so me ba ma gu so san fa 'table' fa 'sea' so ka wen won;
# di ti ga na sa 'lend' la 'will' lan gi mi ga so me ba ma gu so san fa 'table' fa 'sea' so ka wen won;
# ti ta lan gi na sa 'live' li pun fa 'Tokyo' sa 'say' ga te ga sa 'want' ma gu so san fa 'table';
# pi ti ta lan gi na sa 'live' li pun fa 'Tokyo' sa 'say' ga te ga sa 'want' ma gu so san fa 'table' ti ga na sa 'lend' la 'will' lan gi mi ga so me ba ma gu so san fa 'table' fa 'sea' so ka wen won;
# pi di ti ta lan gi na sa 'live' li pun fa 'Tokyo' sa 'say' ga te ga sa 'want' ma gu so san fa 'table' di ti ga na sa 'lend' la 'will' lan gi mi ga so me ba ma gu so san fa 'table' fa 'sea' so ka wen won;
# pis mi ga so fa 'pen' pas;
# pis mi ga so fa 'pen' pos;
# ma tas fis fis fas pos pas so me fa '2' so li fun fa 'binary';
# ma tas mas pos pas so me fa '2' so li fun fa 'binary';
# ma tas mas pos pas so me fa '3' so li fun fa 'binary';
# ma tas mis pos pas pas pas so me fa '8' so li fun fa 'binary';
# ma tas mis pos pas pas pas so me fa '10' so li fun fa 'binary';
# mi ga so ma fa 'pen' so tas mis pos pas pas pas;
# ma tas mos pas pos pas pas pas pas pas pos so me fa '65' so li fun me fa 'number' so la 'natural';
# ma tes mos pas pos pas pas pas pas pas pos so me fa '65' so li fun me fa 'number' so la 'integer';
# ma tus mos pas pos pas pas pas pas pas pos so me fa 'A' so li fun me fa 'character' so la 'ascii';
# ma tas mos pas pos pas pas pas pas pas pos so me fa '97' so li fun me fa 'number' so la 'natural';
# ma tes mos pas pos pas pas pas pas pas pos so me fa '97' so li fun me fa 'number' so la 'integer';
# ma tus mos pas pos pas pas pas pas pas pos so me fa 'a' so li fun me fa 'character' so la 'ascii';
# ma tas fos fos mos pos pos pas pas pas pos pas pas mos pos pas pas pas pas pas pas pas fos mos pas pas pas pas pos pas pas pas mos pas pas pas pas pas pas pas pas so me fa '3296724992' so li fun me fa 'number' so la 'natural';
# ma tas fos fos mos pos pos pas pas pas pos pas pas mos pos pas pas pas pas pas pas pas fos mos pas pas pas pas pos pas pas pas mos pas pas pas pas pas pas pas pas so me fa '-998242304' so li fun me fa 'number' so la 'integer';
# ma tas fos fos mos pos pos pas pas pas pos pas pas mos pos pas pas pas pas pas pas pas fos mos pas pas pas pas pos pas pas pas mos pas pas pas pas pas pas pas pas so me fa '-1024.25' so li fun me fa 'number' so la 'float';
# ma tas fos fos mos pas pos pas pas pas pas pas pas mos pas pos pas pas pos pas pas pos fos mos pas pas pas pas pos pos pos pos mos pos pos pas pos pos pas pos pos so me fa '1078530011' so li fun me fa 'number' so la 'natural';
# ma tas fos fos mos pas pos pas pas pas pas pas pas mos pas pos pas pas pos pas pas pos fos mos pas pas pas pas pos pos pos pos mos pos pos pas pos pos pas pos pos so me fa '1078530011' so li fun me fa 'number' so la 'integer';
# ma tas fos fos mos pas pos pas pas pas pas pas pas mos pas pos pas pas pos pas pas pos fos mos pas pas pas pas pos pos pos pos mos pos pos pas pos pos pas pos pos so me fa '3.1415927410125732' so li fun me fa 'number' so la 'float';
# me ba ma tas fos fos mos pas pos pas pas pas pas pas pas mos pas pos pas pas pos pas pas pos fos mos pas pas pas pas pos pos pos pos mos pos pos pas pos pos pas pos pos so me fa '3.1415927410125732' so li fun me fa 'number' so la 'float' fa 'pi' so wen;
# pu me ba ma tas fos fos mos pas pos pas pas pas pas pas pas mos pas pos pas pas pos pas pas pos fos mos pas pas pas pas pos pos pos pos mos pos pos pas pos pos pas pos pos so me fa '3.1415927410125732' so li fun me fa 'number' so la 'float' fa 'pi' so wen te fa 'SFGPL' na sa 'represent' la 'can' ma fa 'Number' so ma me fa 'point' so la 'floating' so me fa 'precision' so la 'single';
# pis fo fes fos fos mos pas pos pas pas pas pas pas pas mos pas pos pas pas pos pas pas pos fos mos pas pas pas pas pos pos pos pos mos pos pos pas pos pos pas pos pos mis pas pas pas pos;
# pis fo fes fos fos mos pas pos pas pas pas pas pas pas mos pas pos pas pas pos pas pas pos fos mos pas pas pas pas pos pos pos pos mos pos pos pas pos pos pas pos pos mis pas pas pos pos;
# fus fos fos mos pas pos pas pas pas pas pas pas mos pas pos pas pas pos pas pas pos fos mos pas pas pas pas pos pos pos pos mos pos pos pas pos pos pas pos pos mis pas pas pas pos mis pas pas pos pos;
# fus fos fos mos pas pos pas pas pas pas pas pas mos pas pos pas pas pos pas pas pos fos mos pas pas pas pas pos pos pos pos mos pos pos pas pos pos pas pos pos mis pas pas pas pos mis pas pos pos pos;
# pat fa 'f1' fit fat pit;
# pot fa 'f1' fit fit fat fa 'student' fa 'teacher';
# pat fa 'f2' fit fat ba fet pit mas pas pas fet pit mas pas pos;
# pot fa 'f2' fit fit fat pos pas;
# fot fot fit fit fit fit fat ga sa 'go' ge fa 'student' fit fit fit fit fat fa 'apple' la 'high' gu kun fit fit fat ma ga so fa 'student' mi ga so fa 'pen';
# fut fot fot fit fit fit fit fat ga sa 'go' ge fa 'student' fit fit fit fit fat fa 'apple' la 'high' gu kun fit fit fat ma ga so fa 'student' mi ga so fa 'pen' mas pas pas mas pas pos;
# fut fot fot fit fit fit fit fat ga sa 'go' ge fa 'student' fit fit fit fit fat fa 'apple' la 'high' gu kun fit fit fat ma ga so fa 'student' mi ga so fa 'pen' mas pas pas mas pos pos;
# fet fut fot fot fit fit fit fit fat ga sa 'go' ge fa 'student' fit fit fit fit fat fa 'apple' la 'high' gu kun fit fit fat ma ga so fa 'student' mi ga so fa 'pen' mas pas pas mas pos pos mas pas pas;
# te lan gi sa 'study' fa 'English';
# di te lan gi sa 'study' fa 'English';
# di te lan gi pak sa 'study' fa 'English';
# di te lan gi pek sa 'study' fa 'English';
# di te lan gi pik sa 'study' fa 'English';
# di te lan gi puk sa 'study' fa 'English';
# di te lan gi pok sa 'study' fa 'English';
# te lan gi fak sa 'study' fa 'English';
# te lan gi fek sa 'study' fa 'English';
# te lan gi fik sa 'study' fa 'English';
# te lan gi fuk sa 'study' fa 'English';
# te lan gi fok sa 'study' fa 'English';
# ta lan gi na sa 'go' li pun fa 'Tokyo';
# di ta lan gi na sa 'go' li pun fa 'Tokyo';
# di ta lan gi na pak sa 'go' li pun fa 'Tokyo';
# di ta lan gi na pek sa 'go' li pun fa 'Tokyo';
# di ta lan gi na pik sa 'go' li pun fa 'Tokyo';
# di ta lan gi na puk sa 'go' li pun fa 'Tokyo';
# di ta lan gi na pok sa 'go' li pun fa 'Tokyo';
# ta lan gi na fak sa 'go' li pun fa 'Tokyo';
# ta lan gi na fek sa 'go' li pun fa 'Tokyo';
# ta lan gi na fik sa 'go' li pun fa 'Tokyo';
# ta lan gi na fuk sa 'go' li pun fa 'Tokyo';
# ta lan gi na fok sa 'go' li pun fa 'Tokyo';
# te ga sa 'wear' fa 'dress';
# te ga tak sa 'wear' fa 'dress';
# te ga tek sa 'wear' fa 'dress';
# te ga tik sa 'wear' fa 'dress';
# te ga tuk sa 'wear' fa 'dress';
# te ga tuk sa 'wear' fa 'dress';
# ta ga sa 'sit';
# ta ga tak sa 'sit';
# ta ga tek sa 'sit';
# ta ga tik sa 'sit';
# ta ga tuk sa 'sit';
# ta ga tuk sa 'sit';
# te ga sa 'create' fa 'table';
# te ga bik sa 'create' fa 'table';
# di te ga sa 'create' fa 'table';
# te ga bak sa 'create' fa 'table';
# du te ga sa 'create' fa 'table';
# te ga bok sa 'create' fa 'table';
# di te ga bak sa 'create' fa 'table';
# di te ga bik sa 'create' fa 'table';
# di te ga bok sa 'create' fa 'table';
# di te ga bak sa 'create' fa 'table';
# di te ga bik sa 'create' fa 'table';
# di te ga bok sa 'create' fa 'table';
# te ga nak sa 'create' fa 'table';
# te ga nek sa 'create' fa 'table';
# te ga nik sa 'create' fa 'table';
# te ga nuk sa 'create' fa 'table';
# te ga nok sa 'create' fa 'table';
# te ga lak sa 'create' fa 'table';
# te ga lek sa 'create' fa 'table';
# te ga lik sa 'create' fa 'table';
# te ga luk sa 'create' fa 'table';
# te ga lok sa 'create' fa 'table';
# te ga kak sa 'create' fa 'table';
# te ga kek sa 'create' fa 'table';
# te ga kik sa 'create' fa 'table';
# te ga kuk sa 'create' fa 'table';
# te lan gi kok sa 'create' fa 'table';
# te ga gak sa 'create' fa 'table';
# te ga gek sa 'create' fa 'table';
# da te ge gik sa 'create' fa 'table';
# da te ga guk sa 'create' fa 'table';
# da te ga gok sa 'create' fa 'table';
# te ga nak sa 'teach' ma fa 'engineering' so fa 'information';
# te ga nek sa 'teach' ma fa 'engineering' so fa 'information';
# te ga nik sa 'teach' ma fa 'engineering' so fa 'information';
# te ga nuk sa 'teach' ma fa 'engineering' so fa 'information';
# te ga nok sa 'teach' ma fa 'engineering' so fa 'information';
# te ga lak sa 'teach' ma fa 'engineering' so fa 'information';
# te ga lek sa 'teach' ma fa 'engineering' so fa 'information';
# te ga lik sa 'teach' ma fa 'engineering' so fa 'information';
# te ga luk sa 'teach' ma fa 'engineering' so fa 'information';
# te ga lok sa 'teach' ma fa 'engineering' so fa 'information';
# te ga kak sa 'teach' ma fa 'engineering' so fa 'information';
# te ga kek sa 'teach' ma fa 'engineering' so fa 'information';
# te ga kik sa 'teach' ma fa 'engineering' so fa 'information';
# te ga kuk sa 'teach' ma fa 'engineering' so fa 'information';
# te lan gi kok sa 'teach' ma fa 'engineering' so fa 'information';
# te ga gak sa 'teach' ma fa 'engineering' so fa 'information';
# te ga gek sa 'teach' ma fa 'engineering' so fa 'information';
# da te ge gik sa 'teach' ma fa 'engineering' so fa 'information';
# da te ga guk sa 'teach' ma fa 'engineering' so fa 'information';
# da te ga gok sa 'teach' ma fa 'engineering' so fa 'information';
# ta ga nek sa 'swim';
# pa ta ga nek sa 'swim';
# di ta ga nek sa 'swim';
# di pa ta ga nek sa 'swim';
# ta ga na nak sa 'rest' li pin fa 'tomorrow';
# pa ta ga na nak sa 'rest' li pin fa 'tomorrow';
# ta ga na lak sa 'rest' li pin fa 'tomorrow';
# pa ta ga na lak sa 'rest' li pin fa 'tomorrow';
# ta ga na kak sa 'go' li pun fa 'NewYork';
# ta ga na kek sa 'go' li pun fa 'NewYork';
# di ta ga na kak sa 'go' li pun fa 'NewYork';
# di ta ga na kek sa 'go' li pun fa 'NewYork';
# te ga sa 'get' ma fa 'information' so te lan gi nu sa 'create' fa 'table';
# di te ga sa 'get' ma fa 'information' so te lan gi nu sa 'create' fa 'table';
# di moa ga so te lan gi sa 'create' fa 'table' fa 'John';
# di moa ge so te lan gi sa 'create' fa 'table' fa 'John';
# mi ga so ma fa 'apple' so mal pul;
# mi ga so ma fa 'apple' so fil fal bel;
# mi ga so ma fa 'apple' so mel pel bal;
# mi ga so ma fa 'apple' so mel pil pul;
# mi ga so ma fa 'peach' so mal bol;
# mi ga so ma fa 'peach' so mel pel pal;
# mi ga so ma fa 'peach' so fil fil fal pel pal;
# mi mu ga so san fa 'school' so ma fa 'people' so mil bal pil bil;
# mi mu lan gi so san fa 'school' so ma fa 'people' so mil pol pal bol;
# mi mu gu so san fa 'village' so ma fa 'people' so mul pel pul pil pol;
# mi mu gu so san fa 'town' so ma fa 'people' so mul bul pel pil pul;
# mi mu gu so san fa 'city' so ma fa 'people' so mol bel pul pil bul bil;
# mi fa 'Tokyo' so ma fa 'people' so fol mil pel pol pel mol pel pal bil pul pul;
# mi fa 'Japan' so ma fa 'people' so fol mul pel pil bal pol mol pel bel bul bil bil;
# fel mul pel pal pil pol tol mal pal;
# fel mul pel pal pil pol tol mal pul;
# ful mul pel pal pil pol tol mal pal tol mal pel;
# ful mul pel pal pil pol tol mal pal tol mal pil;
# tel tal tul mul pel pal pil pol mel pel bel mel bel pal til mel pel pil mal pul;
# tol tel tal tul mul pel pal pil pol mel pel bel mel bel pal til mel pel pil mal pul;
# tos tol tel tal tul mul pel pal pil pol mel pel bel mel bel pal til mel pel pil mal pul;
# tal tel tal tul mol pul pil bil bel bul mul pel pal pil pol tul mil pul bel pal mel bel pal til mal bol mel pel pil mel bol bal;
# tol tal tel tal tul mol pul pil bil bel bul mul pel pal pil pol tul mil pul bel pal mel bel pal til mal bol mel pel pil mel bol bal;
# tos tol tal tel tal tul mol pul pil bil bel bul mul pel pal pil pol tul mil pul bel pal mel bel pal til mal bol mel pel pil mel bol bal;
# tel tel tal tul mul pel pal pil pol mel pel bel mel bel pal til mel pel pil mal pul tal tel tal tul mol pul pil bil bel bul mul pel pal pil pol tul mil pul bel pal mel bel pal til mal bol mel pel pil mel bol bal;
# tol tel tel tal tul mul pel pal pil pol mel pel bel mel bel pal til mel pel pil mal pul tal tel tal tul mol pul pil bil bel bul mul pel pal pil pol tul mil pul bel pal mel bel pal til mal bol mel pel pil mel bol bal;
# tos tol tel tel tal tul mul pel pal pil pol mel pel bel mel bel pal til mel pel pil mal pul tal tel tal tul mol pul pil bil bel bul mul pel pal pil pol tul mil pul bel pal mel bel pal til mal bol mel pel pil mel bol bal;
# me ma gu so san fa 'bag' so ki wan;
# me ma gu so san fa 'bag' so ki ke wan;
# ja pos mi ga so fa 'pen' pa mi ga so fa 'pen';
# ja pas mi ga so fa 'pen' pa mi ga so fa 'pen';
# pis fa 'true' sal tel mel pel bel mal bol;
# pis fa 'false' sal tel mal bol mel pel bel;
# pis fa 'false' sal tel mal bol mel pel bel;
# pat fa 'condition_func_01' fit fat sal tel mal pil fet pit tol mal pal;
# pat fa 'process_func_01' fit fit fat tal fet pit tol mal pal mal pel tal fet pit tol mal pel mal pil;
# fit fit fit fat mal pal mal pal mal pel;
# tat fit fit fit fat mal pal mal pal mal pel fa 'condition_func_01' fa 'process_func_01';
# pat fa 'condition_func_02' fit fat sal tel mal pil fet pit tol mal pal;
# pat fa 'process_func_02' fit fit fat tal fet pit tol mal pal mal pel tal fet pit tol mal pel mel pel pal;
# fit fit fit fat mal pal mal pal mal pel;
# tat fit fit fit fat mal pal mal pal mal pel fa 'condition_func_02' fa 'process_func_02';
# di te ga sa 'see' ta lan gi na sa 'go' li pun mu lan gi so san fa 'school';
# du te ga sa 'buy' fa 'computer';
# di ta ma fa 'name' so ma fa 'era' so fa 'Japan' na sa 'change' ba ba li fan fa 'Heisei' li fen fa 'Reiwa' li pin fa '2019';
# mo fa 'Tokyo_Sky_Tree' so la 'tall' fa 'Tokyo_Tower';
# me fa 'Tokyo_Sky_Tree' so ka ki la 'tall' li fun ba ma fa 'tower' so fa 'ratio' fa 'the_world';
# me ba fa 'Azabudai_Hills_Mori_JP_Tower' fa 'Tokyo_Tower' so ka la 'tall' wen;

# %%
LangFunc.clearDict()

# %% [markdown]
# # Create a JSON file of the integrated SFGPL corpus

# %%
sc=SFGPLCorpus()
for json_path in out_jsons:
    sc+=SFGPLCorpus.readJson(json_path)

# %%
print(len(sc))
# Out:
# 456

# %%
sc.saveJson(OUT_FILES_DIR+"sample.json")
